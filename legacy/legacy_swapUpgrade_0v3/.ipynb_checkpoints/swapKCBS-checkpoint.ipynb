# %% [markdown]
# ## Import libraries and specify the parameters

# %%
import import_ipynb #to enable importing from notebooks
import mSwapKCBS as sk 
import numpy as np
#testType:2 #state only
#testType:0 #full
#testType:1 #KCBS objective

sk.globalSettings({'cacheFolder':'cached_4_2/','N':5,'testType':0,'hDepth':3,'locMatDepth':2,'solverSettings':{'verbose':False, 'solver':sk.cp.SCS}})
sk.init()
# Out:
# STEP  1 / 5  in progress...
# Initialising Ideal KCBS calculations and performing symbolic computations
# The testType is 0
# Creating projectors etc
# Solving a linear system to find the coefficients for expressing the translation operator as a sum of projectors
# [{a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716}]
# [{a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716}]
# final substitution
# {a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716, a9: 1}
# Solving the cross Π
# [{a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990}]
# [{a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990}]
# final substitution
# {a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990, a9: 1}
# Evaluating F
# Loaded from file
# done
# STEP  1 / 5  done.
#
#
# STEP  2 / 5  in progress...
# Preparing: Sympy meets Cvxpy
# 5
# Fetching the objective
# [P, Pd]
# Constructing dictionaries
# Creating the graph (assumed cyclic for now)
# Simplifying the objective using the graph
# Loading from file
# Done
# [Π_0, Π_1, Π_2, Π_3, Π_4, P, Pd]
# [Π_2*Π_0, Π_3*Π_0, P*Π_0, Pd*Π_0, Π_3*Π_1, Π_4*Π_1, P*Π_1, Pd*Π_1, Π_0*Π_2, Π_4*Π_2, P*Π_2, Pd*Π_2, Π_0*Π_3, Π_1*Π_3, P*Π_3, Pd*Π_3, Π_1*Π_4, Π_2*Π_4, P*Π_4, Pd*Π_4, Π_0*P, Π_1*P, Π_2*P, Π_3*P, Π_4*P, P**2, Π_0*Pd, Π_1*Pd,
_2*P, P*Π_2*P, Pd*Π_2*P, Π_0*Π_3*P, Π_1*Π_3*P, P*Π_3*P, Pd*Π_3*P, Π_1*Π_4*P, Π_2*Π_4*P, P*Π_4*P, Pd*Π_4*P, Π_0*P**2, Π_1*P**2, Π_2*P**2, Π_3*P**2, Π_4*P**2, P**3, Π_2*Π_0*Pd, Π_3*Π_0*Pd, P*Π_0*Pd, Pd*Π_0*Pd, Π_3*Π_1*Pd, Π_4*Π_1*Pd, P*Π_1*Pd, Pd*Π_1*Pd, Π_0*Π_2*Pd, Π_4*Π_2*Pd, P*Π_2*Pd, Pd*Π_2*Pd, Π_0*Π_3*Pd, Π_1*Π_3*Pd, P*Π_3*Pd, Pd*Π_3*Pd, Π_1*Π_4*Pd, Π_2*Π_4*Pd, P*Π_4*Pd, Pd*Π_4*Pd, Π_0*Pd**2, Π_1*Pd**2, Π_2*Pd**2, Π_3*Pd**2, Π_4*Pd**2, Pd**3]
# STEP  2 / 5  done.
#
#
# STEP  3 / 5  in progress...
# Adding constraints from QM to the SDP variables
# Loading from file cached_4_2/with5lSave_4_testType_0_hDepth_3_lenL_192_locDepth2_usePs_True
# Done
# SDP Size var0[0, 0:192]
# Constraints: 16859
# Localising Constraints: 769
# STEP  3 / 5  done.
#
#
# STEP  4 / 5  in progress...
# Creating the objective in terms of the SDP variables
# Constructing the SDP objective from the symbolic objective
# Done
# STEP  4 / 5  done.
#
#
# STEP  5 / 5  in progress...
# Adding observed constraints
# Observed values; Adding constraints
# Done.
# STEP  5 / 5  done.

# %% [markdown]
# ## Input data

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

list1 = np.linspace(0.0, 0.001, num=50)
list2 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] - diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list2.append(val1)
    print("diff is", diff)
    print("val is", val1)
# Out:
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.999998375325079
# sqrt(5) 2.23606797749979
# diff is 0.0
# val is 5.999998375325079
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.985321662695904
# sqrt(5) 2.23606797749979
# diff is 2.0408163265306123e-05
# val is 5.985321662695904
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.958634004230662
# sqrt(5) 2.23606797749979
# diff is 4.0816326530612245e-05
# val is 5.958634004230662
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.918250868879354
# sqrt(5) 2.23606797749979
# diff is 6.122448979591836e-05
# val is 5.918250868879354
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.8681060359968376
# sqrt(5) 2.23606797749979
# diff is 8.163265306122449e-05
# val is 5.8681060359968376
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.806039189514637
# sqrt(5) 2.23606797749979
# diff is 0.00010204081632653062
# val is 5.806039189514637
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.734230625342964
# sqrt(5) 2.23606797749979
# diff is 0.00012244897959183673
# val is 5.734230625342964
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.653609012048679
# sqrt(5) 2.23606797749979
# diff is 0.00014285714285714287
# val is 5.653609012048679
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.567478294310279
# sqrt(5) 2.23606797749979
# diff is 0.00016326530612244898
# val is 5.567478294310279
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.47501255362923
# sqrt(5) 2.23606797749979
# diff is 0.0001836734693877551
# val is 5.47501255362923
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.378182505040689
# sqrt(5) 2.23606797749979
# diff is 0.00020408163265306123
# val is 5.378182505040689
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.279310677066217
# sqrt(5) 2.23606797749979
# diff is 0.00022448979591836734
# val is 5.279310677066217
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...

# %%
list2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-017990ea2ce6> in <module>
# ----> 1 list2
#
# NameError: name 'list2' is not defined

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

list1 = np.linspace(0.00022448979591836734, 0.001, num=30)
list2 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] - diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list2.append(val1)
    print("diff is", diff)
    print("val is", val1)
# Out:
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.8549877713603165
# sqrt(5) 2.23606797749979
# diff is 0.00022448979591836734
# val is 5.8549877713603165
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.70673416031995
# sqrt(5) 2.23606797749979
# diff is 0.00025123152709359607
# val is 5.70673416031995
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.557826127207425
# sqrt(5) 2.23606797749979
# diff is 0.0002779732582688248
# val is 5.557826127207425
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.407389777322582
# sqrt(5) 2.23606797749979
# diff is 0.0003047149894440535
# val is 5.407389777322582
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.26069248876821
# sqrt(5) 2.23606797749979
# diff is 0.0003314567206192822
# val is 5.26069248876821
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.116641167274114
# sqrt(5) 2.23606797749979
# diff is 0.0003581984517945109
# val is 5.116641167274114
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.976783032109579
# sqrt(5) 2.23606797749979
# diff is 0.0003849401829697396
# val is 4.976783032109579
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.841576362255677
# sqrt(5) 2.23606797749979
# diff is 0.00041168191414496833
# val is 4.841576362255677
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.710367853879933
# sqrt(5) 2.23606797749979
# diff is 0.00043842364532019703
# val is 4.710367853879933
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.583305078389756
# sqrt(5) 2.23606797749979
# diff is 0.00046516537649542573
# val is 4.583305078389756
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.459796423101613
# sqrt(5) 2.23606797749979
# diff is 0.0004919071076706545
# val is 4.459796423101613
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.340010356291876
# sqrt(5) 2.23606797749979
# diff is 0.0005186488388458832
# val is 4.340010356291876
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.223767070128009
# sqrt(5) 2.23606797749979
# diff is 0.0005453905700211119
# val is 4.223767070128009
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.111036484293034
# sqrt(5) 2.23606797749979
# diff is 0.0005721323011963406
# val is 4.111036484293034
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.001780683553427
# sqrt(5) 2.23606797749979
# diff is 0.0005988740323715693
# val is 4.001780683553427
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.896143831523922
# sqrt(5) 2.23606797749979
# diff is 0.000625615763546798
# val is 3.896143831523922
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.794075230142097
# sqrt(5) 2.23606797749979
# diff is 0.0006523574947220267
# val is 3.794075230142097
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.6955672840964033
# sqrt(5) 2.23606797749979
# diff is 0.0006790992258972554
# val is 3.6955672840964033
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.600778416430983
# sqrt(5) 2.23606797749979
# diff is 0.0007058409570724841
# val is 3.600778416430983
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.509639496255474
# sqrt(5) 2.23606797749979
# diff is 0.0007325826882477129
# val is 3.509639496255474
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.4222759036300996
# sqrt(5) 2.23606797749979
# diff is 0.0007593244194229416
# val is 3.4222759036300996
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.3388469195622434
# sqrt(5) 2.23606797749979
# diff is 0.0007860661505981703
# val is 3.3388469195622434
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.2590915209571234
# sqrt(5) 2.23606797749979
# diff is 0.000812807881773399
# val is 3.2590915209571234
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.183007230487401
# sqrt(5) 2.23606797749979
# diff is 0.0008395496129486277
# val is 3.183007230487401
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.110433257235969
# sqrt(5) 2.23606797749979
# diff is 0.0008662913441238564
# val is 3.110433257235969
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.0411665563409738
# sqrt(5) 2.23606797749979
# diff is 0.0008930330752990851
# val is 3.0411665563409738
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.9750204360524277
# sqrt(5) 2.23606797749979
# diff is 0.0009197748064743138
# val is 2.9750204360524277
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.9118381119962935
# sqrt(5) 2.23606797749979
# diff is 0.0009465165376495426
# val is 2.9118381119962935
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.8514684734616207
# sqrt(5) 2.23606797749979
# diff is 0.0009732582688247713
# val is 2.8514684734616207
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.793615162045649
# sqrt(5) 2.23606797749979
# diff is 0.001
# val is 2.793615162045649

# %%
list2
# Out:
# [5.8549877713603165, 5.70673416031995, 5.557826127207425, 5.407389777322582, 5
# .26069248876821, 5.116641167274114, 4.976783032109579, 4.841576362255677, 4.71
# 0367853879933, 4.583305078389756, 4.459796423101613, 4.340010356291876, 4.2237
# 67070128009, 4.111036484293034, 4.001780683553427, 3.896143831523922, 3.794075
# 230142097, 3.6955672840964033, 3.600778416430983, 3.509639496255474, 3.4222759
# 036300996, 3.3388469195622434, 3.2590915209571234, 3.183007230487401, 3.110433
# 257235969, 3.0411665563409738, 2.9750204360524277, 2.9118381119962935, 2.85146
# 84734616207, 2.793615162045649]

# %%
list1
# Out:
# array([0.00022449, 0.00025123, 0.00027797, 0.00030471, 0.00033146,
#        0.0003582 , 0.00038494, 0.00041168, 0.00043842, 0.00046517,
#        0.00049191, 0.00051865, 0.00054539, 0.00057213, 0.00059887,
#        0.00062562, 0.00065236, 0.0006791 , 0.00070584, 0.00073258,
#        0.00075932, 0.00078607, 0.00081281, 0.00083955, 0.00086629,
#        0.00089303, 0.00091977, 0.00094652, 0.00097326, 0.001     ])

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

list3 = np.linspace(0.001, 0.047, num=30)
list4 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] - diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list4.append(val1)
    print("diff is", diff)
    print("val is", val1)
# Out:
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.8549877713603165
# sqrt(5) 2.23606797749979
# diff is 0.00022448979591836734
# val is 5.8549877713603165
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.70673416031995
# sqrt(5) 2.23606797749979
# diff is 0.00025123152709359607
# val is 5.70673416031995
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
