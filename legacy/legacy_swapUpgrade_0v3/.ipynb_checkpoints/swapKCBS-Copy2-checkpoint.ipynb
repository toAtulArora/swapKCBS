# %% [markdown]
# ## Import libraries and specify the parameters

# %%
import import_ipynb #to enable importing from notebooks
import mSwapKCBS as sk 
import numpy as np
#testType:2 #state only
#testType:0 #full
#testType:1 #KCBS objective

sk.globalSettings({'cacheFolder':'cached_4_2/','N':5,'testType':0,'hDepth':3,'locMatDepth':2,'solverSettings':{'verbose':False, 'solver':sk.cp.SCS}})
sk.init()
# Out:
# importing Jupyter notebook from mSwapKCBS.ipynb
# STEP  1 / 5  in progress...
# Initialising Ideal KCBS calculations and performing symbolic computations
# The testType is 0
# Creating projectors etc
# Solving a linear system to find the coefficients for expressing the translation operator as a sum of projectors
# [{a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716}]
# [{a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716}]
# final substitution
# {a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716, a9: 1}
# Solving the cross Π
# [{a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990}]
# [{a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990}]
# final substitution
# {a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990, a9: 1}
# Evaluating F
# Loaded from file
# done
# STEP  1 / 5  done.
#
#
# STEP  2 / 5  in progress...
# Preparing: Sympy meets Cvxpy
# 5
# Fetching the objective
# [P, Pd]
# Constructing dictionaries
# Creating the graph (assumed cyclic for now)
# Simplifying the objective using the graph
# Loading from file
# Done
# [Π_0, Π_1, Π_2, Π_3, Π_4, P, Pd]
# [Π_2*Π_0, Π_3*Π_0, P*Π_0, Pd*Π_0, Π_3*Π_1, Π_4*Π_1, P*Π_1, Pd*Π_1, Π_0*Π_2, Π_4*Π_2, P*Π_2, Pd*Π_2, Π_0*Π_3, Π_1*Π_3, P*Π_3, Pd*Π_3, Π_1*Π_4, Π_2*Π_4, P*Π_4, Pd*Π_4, Π_0*P, Π_1*P, Π_2*P, Π_3*P, Π_4*P, P**2, Π_0*Pd, Π_1*Pd, Π_2*Pd, Π_3*P
, Pd*Π_3*P, Π_1*Π_4*P, Π_2*Π_4*P, P*Π_4*P, Pd*Π_4*P, Π_0*P**2, Π_1*P**2, Π_2*P**2, Π_3*P**2, Π_4*P**2, P**3, Π_2*Π_0*Pd, Π_3*Π_0*Pd, P*Π_0*Pd, Pd*Π_0*Pd, Π_3*Π_1*Pd, Π_4*Π_1*Pd, P*Π_1*Pd, Pd*Π_1*Pd, Π_0*Π_2*Pd, Π_4*Π_2*Pd, P*Π_2*Pd, Pd*Π_2*Pd, Π_0*Π_3*Pd, Π_1*Π_3*Pd, P*Π_3*Pd, Pd*Π_3*Pd, Π_1*Π_4*Pd, Π_2*Π_4*Pd, P*Π_4*Pd, Pd*Π_4*Pd, Π_0*Pd**2, Π_1*Pd**2, Π_2*Pd**2, Π_3*Pd**2, Π_4*Pd**2, Pd**3]
# STEP  2 / 5  done.
#
#
# STEP  3 / 5  in progress...
# Adding constraints from QM to the SDP variables
# Loading from file cached_4_2/with5lSave_4_testType_0_hDepth_3_lenL_192_locDepth2_usePs_True
# Done
# SDP Size var0[0, 0:192]
# Constraints: 16859
# Localising Constraints: 769
# STEP  3 / 5  done.
#
#
# STEP  4 / 5  in progress...
# Creating the objective in terms of the SDP variables
# Constructing the SDP objective from the symbolic objective
# Done
# STEP  4 / 5  done.
#
#
# STEP  5 / 5  in progress...
# Adding observed constraints
# Observed values; Adding constraints
# Done.
# STEP  5 / 5  done.

# %% [markdown]
# ## Input data

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

list1 = np.linspace(0.0, 0.001, num=50)
list2 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] - diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list2.append(val1)
    print("diff is", diff)
    print("val is", val1)
# Out:
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.999905267503888
# sqrt(5) 2.23606797749979
# diff is 0.0
# val is 5.999905267503888
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.999431729717556
# sqrt(5) 2.23606797749979
# diff is 2.0408163265306123e-05
# val is 5.999431729717556
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.999110325639712
# sqrt(5) 2.23606797749979
# diff is 4.0816326530612245e-05
# val is 5.999110325639712
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.997226588239393
# sqrt(5) 2.23606797749979
# diff is 6.122448979591836e-05
# val is 5.997226588239393
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.995616312581479
# sqrt(5) 2.23606797749979
# diff is 8.163265306122449e-05
# val is 5.995616312581479
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.993749666175793
# sqrt(5) 2.23606797749979
# diff is 0.00010204081632653062
# val is 5.993749666175793
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.991432950138858
# sqrt(5) 2.23606797749979
# diff is 0.00012244897959183673
# val is 5.991432950138858
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.988063855738053
# sqrt(5) 2.23606797749979
# diff is 0.00014285714285714287
# val is 5.988063855738053
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.982268916500206
# sqrt(5) 2.23606797749979
# diff is 0.00016326530612244898
# val is 5.982268916500206
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.965674538671804
# sqrt(5) 2.23606797749979
# diff is 0.0001836734693877551
# val is 5.965674538671804
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.880937900850885
# sqrt(5) 2.23606797749979
# diff is 0.00020408163265306123
# val is 5.880937900850885
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.0289844983836933
# sqrt(5) 2.23606797749979
# diff is 0.0007755102040816326
# val is 3.0289844983836933
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.975266679076522
# sqrt(5) 2.23606797749979
# diff is 0.0007959183673469387
# val is 2.975266679076522
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.923431563873593
# sqrt(5) 2.23606797749979
# diff is 0.0008163265306122449
# val is 2.923431563873593
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.8734864744594866
# sqrt(5) 2.23606797749979
# diff is 0.000836734693877551
# val is 2.8734864744594866
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.8252971258692456
# sqrt(5) 2.23606797749979
# diff is 0.0008571428571428571
# val is 2.8252971258692456
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.7787805653545377
# sqrt(5) 2.23606797749979
# diff is 0.0008775510204081633
# val is 2.7787805653545377
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.733896388529524
# sqrt(5) 2.23606797749979
# diff is 0.0008979591836734694
# val is 2.733896388529524
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.6905620710810307
# sqrt(5) 2.23606797749979
# diff is 0.0009183673469387755
# val is 2.6905620710810307
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.6487163007447387
# sqrt(5) 2.23606797749979
# diff is 0.0009387755102040817
# val is 2.6487163007447387
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.6083136611461843
# sqrt(5) 2.23606797749979
# diff is 0.0009591836734693877
# val is 2.6083136611461843
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.569311244302452
# sqrt(5) 2.23606797749979
# diff is 0.0009795918367346938
# val is 2.569311244302452
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.531674515480977
# sqrt(5) 2.23606797749979
# diff is 0.001
# val is 2.531674515480977

# %%
list2
# Out:
# [5.999905267503888, 5.999431729717556, 5.999110325639712, 5.997226588239393, 5
# .995616312581479, 5.993749666175793, 5.991432950138858, 5.988063855738053, 5.9
# 82268916500206, 5.965674538671804, 5.880937900850885, 5.783222842137276, 5.674
# 343440721197, 5.5507065566884854, 5.405598776429481, 5.233015460096279, 5.0357
# 57143518759, 4.833567160417195, 4.65133540861377, 4.502499667475271, 4.3844849
# 11083736, 4.286537029203912, 4.197615188428175, 4.111309759925509, 4.025559549
# 397474, 3.9403779224518645, 3.8562708532462135, 3.773790843794486, 3.693318005
# 373765, 3.6150603467121516, 3.539173977090152, 3.465829224475218, 3.3954177637
# 793084, 3.3283349639781896, 3.264133419112691, 3.202101674581812, 3.1422675693
# 994755, 3.084542410144073, 3.0289844983836933, 2.975266679076522, 2.9234315638
# 73593, 2.8734864744594866, 2.8252971258692456, 2.7787805653545377, 2.733896388
# 529524, 2.6905620710810307, 2.6487163007447387, 2.6083136611461843, 2.56931124
# 4302452, 2.531674515480977]

# %%
list1
# Out:
# array([0.00000000e+00, 2.04081633e-05, 4.08163265e-05, 6.12244898e-05,
#        8.16326531e-05, 1.02040816e-04, 1.22448980e-04, 1.42857143e-04,
#        1.63265306e-04, 1.83673469e-04, 2.04081633e-04, 2.24489796e-04,
#        2.44897959e-04, 2.65306122e-04, 2.85714286e-04, 3.06122449e-04,
#        3.26530612e-04, 3.46938776e-04, 3.67346939e-04, 3.87755102e-04,
#        4.08163265e-04, 4.28571429e-04, 4.48979592e-04, 4.69387755e-04,
#        4.89795918e-04, 5.10204082e-04, 5.30612245e-04, 5.51020408e-04,
#        5.71428571e-04, 5.91836735e-04, 6.12244898e-04, 6.32653061e-04,
#        6.53061224e-04, 6.73469388e-04, 6.93877551e-04, 7.14285714e-04,
#        7.34693878e-04, 7.55102041e-04, 7.75510204e-04, 7.95918367e-04,
#        8.16326531e-04, 8.36734694e-04, 8.57142857e-04, 8.77551020e-04,
#        8.97959184e-04, 9.18367347e-04, 9.38775510e-04, 9.59183673e-04,
#        9.79591837e-04, 1.00000000e-03])

# %%
import pandas
df = pandas.DataFrame(data={"Deviaton": list1, "Fidelity": list2})
df.to_csv("./Fid_KCBS_1.csv", sep=',',index=False)

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

list1 = np.linspace(0.00022448979591836734, 0.001, num=30)
list2 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] - diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list2.append(val1)
    print("diff is", diff)
    print("val is", val1)

# %%
list2
# Out:
# [5.8549877713603165, 5.70673416031995, 5.557826127207425, 5.407389777322582, 5
# .26069248876821, 5.116641167274114, 4.976783032109579, 4.841576362255677, 4.71
# 0367853879933, 4.583305078389756, 4.459796423101613, 4.340010356291876, 4.2237
# 67070128009, 4.111036484293034, 4.001780683553427, 3.896143831523922, 3.794075
# 230142097, 3.6955672840964033, 3.600778416430983, 3.509639496255474, 3.4222759
# 036300996, 3.3388469195622434, 3.2590915209571234, 3.183007230487401, 3.110433
# 257235969, 3.0411665563409738, 2.9750204360524277, 2.9118381119962935, 2.85146
# 84734616207, 2.793615162045649]

# %%
list1
# Out:
# array([0.00022449, 0.00025123, 0.00027797, 0.00030471, 0.00033146,
#        0.0003582 , 0.00038494, 0.00041168, 0.00043842, 0.00046517,
#        0.00049191, 0.00051865, 0.00054539, 0.00057213, 0.00059887,
#        0.00062562, 0.00065236, 0.0006791 , 0.00070584, 0.00073258,
#        0.00075932, 0.00078607, 0.00081281, 0.00083955, 0.00086629,
#        0.00089303, 0.00091977, 0.00094652, 0.00097326, 0.001     ])

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

list3 = np.linspace(0.001, 0.047, num=30)
list4 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] - diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list4.append(val1)
    print("diff is", diff)
    print("val is", val1)
# Out:
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.8549877713603165
# sqrt(5) 2.23606797749979
# diff is 0.00022448979591836734
# val is 5.8549877713603165
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.70673416031995
# sqrt(5) 2.23606797749979
# diff is 0.00025123152709359607
# val is 5.70673416031995
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
