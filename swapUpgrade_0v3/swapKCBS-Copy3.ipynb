# %% [markdown]
# ## Import libraries and specify the parameters

# %%
import import_ipynb #to enable importing from notebooks
import mSwapKCBS as sk 
import numpy as np
#testType:2 #state only
#testType:0 #full
#testType:1 #KCBS objective

sk.globalSettings({'cacheFolder':'cached_4_2/','N':5,'testType':0,'hDepth':3,'locMatDepth':2,'solverSettings':{'verbose':False, 'solver':sk.cp.SCS}})
sk.init()
# Out:
# importing Jupyter notebook from mSwapKCBS.ipynb
# STEP  1 / 5  in progress...
# Initialising Ideal KCBS calculations and performing symbolic computations
# The testType is 0
# Creating projectors etc
# Solving a linear system to find the coefficients for expressing the translation operator as a sum of projectors
# [{a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716}]
# [{a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716}]
# final substitution
# {a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716, a9: 1}
# Solving the cross Π
# [{a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990}]
# [{a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990}]
# final substitution
# {a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990, a9: 1}
# Evaluating F
# Loaded from file
# done
# STEP  1 / 5  done.
#
#
# STEP  2 / 5  in progress...
# Preparing: Sympy meets Cvxpy
# 5
# Fetching the objective
# [P, Pd]
# Constructing dictionaries
# Creating the graph (assumed cyclic for now)
# Simplifying the objective using the graph
# Loading from file
# Done
# [Π_0, Π_1, Π_2, Π_3, Π_4, P, Pd]
# [Π_2*Π_0, Π_3*Π_0, P*Π_0, Pd*Π_0, Π_3*Π_1, Π_4*Π_1, P*Π_1, Pd*Π_1, Π_0*Π_2, Π_4*Π_2, P*Π_2, Pd*Π_2, Π_0*Π_3, Π_1*Π_3, P*Π_3, Pd*Π_3, Π_1*Π_4, Π_2*Π_4, P*Π_4, Pd*Π_4, Π_0*P, Π_1*P, Π_2*P, Π_3*P, Π_4*P, P**2, Π_0*Pd, Π_1*Pd, Π_2*Pd, Π_3*Pd, Π_4*Pd
4*P, Π_2*Π_4*P, P*Π_4*P, Pd*Π_4*P, Π_0*P**2, Π_1*P**2, Π_2*P**2, Π_3*P**2, Π_4*P**2, P**3, Π_2*Π_0*Pd, Π_3*Π_0*Pd, P*Π_0*Pd, Pd*Π_0*Pd, Π_3*Π_1*Pd, Π_4*Π_1*Pd, P*Π_1*Pd, Pd*Π_1*Pd, Π_0*Π_2*Pd, Π_4*Π_2*Pd, P*Π_2*Pd, Pd*Π_2*Pd, Π_0*Π_3*Pd, Π_1*Π_3*Pd, P*Π_3*Pd, Pd*Π_3*Pd, Π_1*Π_4*Pd, Π_2*Π_4*Pd, P*Π_4*Pd, Pd*Π_4*Pd, Π_0*Pd**2, Π_1*Pd**2, Π_2*Pd**2, Π_3*Pd**2, Π_4*Pd**2, Pd**3]
# STEP  2 / 5  done.
#
#
# STEP  3 / 5  in progress...
# Adding constraints from QM to the SDP variables
# Loading from file cached_4_2/with5lSave_4_testType_0_hDepth_3_lenL_192_locDepth2_usePs_True
# Done
# SDP Size var0[0, 0:192]
# Constraints: 16859
# Localising Constraints: 769
# STEP  3 / 5  done.
#
#
# STEP  4 / 5  in progress...
# Creating the objective in terms of the SDP variables
# Constructing the SDP objective from the symbolic objective
# Done
# STEP  4 / 5  done.
#
#
# STEP  5 / 5  in progress...
# Adding observed constraints
# Observed values; Adding constraints
# Done.
# STEP  5 / 5  done.

# %% [markdown]
# ## Input data

# %%
N=5
obsData= [0.43]*5
diff = (np.sqrt(5) -2.15)/5.0
list1 = np.linspace(0.0, diff, num=50)
list2 = []
count = 21
while count <= 25:
    diff1 = list1[count-1]
    count = count +1
    obsData= [0.43]*5
    for i in range(len(obsData)):
        obsData[i] = obsData[i] + diff1
    tot = sum(obsData)
    print("Total is", tot)
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list2.append(val1)
    print("diff is", diff)
    print("val is", val1)
# Out:
# Total is 2.185129786734608
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.4585559193835387
# sqrt(5) 2.23606797749979
# diff is 0.01721359549995798
# val is 3.4585559193835387
# Total is 2.1868862760713386
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.498375879352873
# sqrt(5) 2.23606797749979
# diff is 0.01721359549995798
# val is 3.498375879352873
# Total is 2.188642765408069
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.539744218278059
# sqrt(5) 2.23606797749979
# diff is 0.01721359549995798
# val is 3.539744218278059
# Total is 2.1903992547447992
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.582698690569391
# sqrt(5) 2.23606797749979
# diff is 0.01721359549995798
# val is 3.582698690569391
# Total is 2.19215574408153
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.627302183563524
# sqrt(5) 2.23606797749979
# diff is 0.01721359549995798
# val is 3.627302183563524

# %%
list2
# Out:
# [3.4585559193835387, 3.498375879352873, 3.539744218278059, 3.582698690569391,
# 3.627302183563524]

# %%
list1
# Out:
# array([0.        , 0.0003513 , 0.0007026 , 0.00105389, 0.00140519,
#        0.00175649, 0.00210779, 0.00245909, 0.00281038, 0.00316168,
#        0.00351298, 0.00386428, 0.00421557, 0.00456687, 0.00491817,
#        0.00526947, 0.00562077, 0.00597206, 0.00632336, 0.00667466,
#        0.00702596, 0.00737726, 0.00772855, 0.00807985, 0.00843115,
#        0.00878245, 0.00913374, 0.00948504, 0.00983634, 0.01018764,
#        0.01053894, 0.01089023, 0.01124153, 0.01159283, 0.01194413,
#        0.01229543, 0.01264672, 0.01299802, 0.01334932, 0.01370062,
#        0.01405191, 0.01440321, 0.01475451, 0.01510581, 0.01545711,
#        0.0158084 , 0.0161597 , 0.016511  , 0.0168623 , 0.0172136 ])

# %%
import pandas
df = pandas.DataFrame(data={"Fidelity": list2})
df.to_csv("./Fid_KCBS_35.csv", sep=',',index=False)

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

list1 = np.linspace(0.00022448979591836734, 0.001, num=30)
list2 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] - diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list2.append(val1)
    print("diff is", diff)
    print("val is", val1)
# Out:
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.995234867570599
# sqrt(5) 2.23606797749979
# diff is 0.00022448979591836734
# val is 5.995234867570599
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.990414599089788
# sqrt(5) 2.23606797749979
# diff is 0.00025123152709359607
# val is 5.990414599089788
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.981022474301778
# sqrt(5) 2.23606797749979
# diff is 0.0002779732582688248
# val is 5.981022474301778
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.9085534830678625
# sqrt(5) 2.23606797749979
# diff is 0.0003047149894440535
# val is 5.9085534830678625
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.7643646270767
# sqrt(5) 2.23606797749979
# diff is 0.0003314567206192822
# val is 5.7643646270767
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.6025124717251416
# sqrt(5) 2.23606797749979
# diff is 0.0003581984517945109
# val is 5.6025124717251416
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.4108632261419345
# sqrt(5) 2.23606797749979
# diff is 0.0003849401829697396
# val is 5.4108632261419345
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.175884153676228
# sqrt(5) 2.23606797749979
# diff is 0.00041168191414496833
# val is 5.175884153676228
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.91223264670468
# sqrt(5) 2.23606797749979
# diff is 0.00043842364532019703
# val is 4.91223264670468
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.669896034029906
# sqrt(5) 2.23606797749979
# diff is 0.00046516537649542573
# val is 4.669896034029906
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.482183191700218
# sqrt(5) 2.23606797749979
# diff is 0.0004919071076706545
# val is 4.482183191700218
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.342630040223032
# sqrt(5) 2.23606797749979
# diff is 0.0005186488388458832
# val is 4.342630040223032
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.2281452316325465
# sqrt(5) 2.23606797749979
# diff is 0.0005453905700211119
# val is 4.2281452316325465
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.121425011113335
# sqrt(5) 2.23606797749979
# diff is 0.0005721323011963406
# val is 4.121425011113335
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.01655292384622
# sqrt(5) 2.23606797749979
# diff is 0.0005988740323715693
# val is 4.01655292384622
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.91322109177559
# sqrt(5) 2.23606797749979
# diff is 0.000625615763546798
# val is 3.91322109177559
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.812258577171137
# sqrt(5) 2.23606797749979
# diff is 0.0006523574947220267
# val is 3.812258577171137
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.714433426057755
# sqrt(5) 2.23606797749979
# diff is 0.0006790992258972554
# val is 3.714433426057755
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.6201179253806632
# sqrt(5) 2.23606797749979
# diff is 0.0007058409570724841
# val is 3.6201179253806632
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.5295099204064107
# sqrt(5) 2.23606797749979
# diff is 0.0007325826882477129
# val is 3.5295099204064107
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.4428650352681767
# sqrt(5) 2.23606797749979
# diff is 0.0007593244194229416
# val is 3.4428650352681767
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.3608036324207333
# sqrt(5) 2.23606797749979
# diff is 0.0007860661505981703
# val is 3.3608036324207333
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.2834957321561067
# sqrt(5) 2.23606797749979
# diff is 0.000812807881773399
# val is 3.2834957321561067
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.209588401091612
# sqrt(5) 2.23606797749979
# diff is 0.0008395496129486277
# val is 3.209588401091612
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.138887335537966
# sqrt(5) 2.23606797749979
# diff is 0.0008662913441238564
# val is 3.138887335537966
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.071271629650614
# sqrt(5) 2.23606797749979
# diff is 0.0008930330752990851
# val is 3.071271629650614
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.0066540349699413
# sqrt(5) 2.23606797749979
# diff is 0.0009197748064743138
# val is 3.0066540349699413
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.9446685042853242
# sqrt(5) 2.23606797749979
# diff is 0.0009465165376495426
# val is 2.9446685042853242
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.885390063145739
# sqrt(5) 2.23606797749979
# diff is 0.0009732582688247713
# val is 2.885390063145739
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.828646145077664
# sqrt(5) 2.23606797749979
# diff is 0.001
# val is 2.828646145077664

# %%
list2
# Out:
# [5.995234867570599, 5.990414599089788, 5.981022474301778, 5.9085534830678625,
# 5.7643646270767, 5.6025124717251416, 5.4108632261419345, 5.175884153676228, 4.
# 91223264670468, 4.669896034029906, 4.482183191700218, 4.342630040223032, 4.228
# 1452316325465, 4.121425011113335, 4.01655292384622, 3.91322109177559, 3.812258
# 577171137, 3.714433426057755, 3.6201179253806632, 3.5295099204064107, 3.442865
# 0352681767, 3.3608036324207333, 3.2834957321561067, 3.209588401091612, 3.13888
# 7335537966, 3.071271629650614, 3.0066540349699413, 2.9446685042853242, 2.88539
# 0063145739, 2.828646145077664]

# %%
list1
# Out:
# array([0.00022449, 0.00025123, 0.00027797, 0.00030471, 0.00033146,
#        0.0003582 , 0.00038494, 0.00041168, 0.00043842, 0.00046517,
#        0.00049191, 0.00051865, 0.00054539, 0.00057213, 0.00059887,
#        0.00062562, 0.00065236, 0.0006791 , 0.00070584, 0.00073258,
#        0.00075932, 0.00078607, 0.00081281, 0.00083955, 0.00086629,
#        0.00089303, 0.00091977, 0.00094652, 0.00097326, 0.001     ])

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

list3 = np.linspace(0.001, 0.047, num=30)
list4 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] - diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list4.append(val1)
    print("diff is", diff)
    print("val is", val1)
# Out:
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.995234867570599
# sqrt(5) 2.23606797749979
# diff is 0.00022448979591836734
# val is 5.995234867570599
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.990414599089788
# sqrt(5) 2.23606797749979
# diff is 0.00025123152709359607
# val is 5.990414599089788
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5