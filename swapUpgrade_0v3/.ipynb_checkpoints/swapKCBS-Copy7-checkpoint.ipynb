# %% [markdown]
# ## Import libraries and specify the parameters

# %%
import import_ipynb #to enable importing from notebooks
import mSwapKCBS as sk 
import numpy as np
#testType:2 #state only
#testType:0 #full
#testType:1 #KCBS objective

sk.globalSettings({'cacheFolder':'cached_4_2/','N':5,'testType':0,'hDepth':3,'locMatDepth':2,'solverSettings':{'verbose':False, 'solver':sk.cp.SCS}})
sk.init()
# Out:
# importing Jupyter notebook from mSwapKCBS.ipynb
# STEP  1 / 5  in progress...
# Initialising Ideal KCBS calculations and performing symbolic computations
# The testType is 0
# Creating projectors etc
# Solving a linear system to find the coefficients for expressing the translation operator as a sum of projectors
# [{a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716}]
# [{a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716}]
# final substitution
# {a0: -0.272019649514068, a1: -0.485868271756648, a2: -2.05817102727150, a3: -6.28562544506058e-16, a4: 2.77032771530716, a5: -1.15229372655726, a6: -4.82849874257865, a7: 3.33019067678556, a8: 2.77032771530716, a9: 1}
# Solving the cross Π
# [{a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990}]
# [{a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990}]
# final substitution
# {a0: -1.00000000000000, a1: -1.00000000000000, a2: -2.10343297734178e-15, a3: -1.77094079760213e-15, a4: 4.23606797749979, a5: -4.23606797749979, a6: -4.23606797749979, a7: 2.61803398874990, a8: 2.61803398874990, a9: 1}
# Evaluating F
# Loaded from file
# done
# STEP  1 / 5  done.
#
#
# STEP  2 / 5  in progress...
# Preparing: Sympy meets Cvxpy
# 5
# Fetching the objective
# [P, Pd]
# Constructing dictionaries
# Creating the graph (assumed cyclic for now)
# Simplifying the objective using the graph
# Loading from file
# Done
# [Π_0, Π_1, Π_2, Π_3, Π_4, P, Pd]
# [Π_2*Π_0, Π_3*Π_0, P*Π_0, Pd*Π_0, Π_3*Π_1, Π_4*Π_1, P*Π_1, Pd*Π_1, Π_0*Π_2, Π_4*Π_2, P*Π_2, Pd*Π_2, Π_0*Π_3, Π_1*Π_3, P*Π_3, Pd*Π_3, Π_1*Π_4, Π_2*Π_4, P*Π_4, Pd*Π_4, Π_0*P, Π_1*P, Π_2*P, Π_3*P, Π_4*P, P**2, Π_0*Pd, Π_1*Pd, Π_2*Pd, Π_
P*Π_3*P, Pd*Π_3*P, Π_1*Π_4*P, Π_2*Π_4*P, P*Π_4*P, Pd*Π_4*P, Π_0*P**2, Π_1*P**2, Π_2*P**2, Π_3*P**2, Π_4*P**2, P**3, Π_2*Π_0*Pd, Π_3*Π_0*Pd, P*Π_0*Pd, Pd*Π_0*Pd, Π_3*Π_1*Pd, Π_4*Π_1*Pd, P*Π_1*Pd, Pd*Π_1*Pd, Π_0*Π_2*Pd, Π_4*Π_2*Pd, P*Π_2*Pd, Pd*Π_2*Pd, Π_0*Π_3*Pd, Π_1*Π_3*Pd, P*Π_3*Pd, Pd*Π_3*Pd, Π_1*Π_4*Pd, Π_2*Π_4*Pd, P*Π_4*Pd, Pd*Π_4*Pd, Π_0*Pd**2, Π_1*Pd**2, Π_2*Pd**2, Π_3*Pd**2, Π_4*Pd**2, Pd**3]
# STEP  2 / 5  done.
#
#
# STEP  3 / 5  in progress...
# Adding constraints from QM to the SDP variables
# Loading from file cached_4_2/with5lSave_4_testType_0_hDepth_3_lenL_192_locDepth2_usePs_True
# Done
# SDP Size var0[0, 0:192]
# Constraints: 16859
# Localising Constraints: 769
# STEP  3 / 5  done.
#
#
# STEP  4 / 5  in progress...
# Creating the objective in terms of the SDP variables
# Constructing the SDP objective from the symbolic objective
# Done
# STEP  4 / 5  done.
#
#
# STEP  5 / 5  in progress...
# Adding observed constraints
# Observed values; Adding constraints
# Done.
# STEP  5 / 5  done.

# %% [markdown]
# ## Input data

# %%
N=5
obsData= [0.4]*5
diff = (np.sqrt(5) -2.0)/5.0
list1 = np.linspace(0.0, diff, num=50)
list2 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] + diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list2.append(val1)
    print("diff is", diff)
    print("val is", val1)
# Out:
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.0378734542869332
# sqrt(5) 2.23606797749979
# diff is 0.0
# val is 2.0378734542869332
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.05133666324123
# sqrt(5) 2.23606797749979
# diff is 0.0009635427653052645
# val is 2.05133666324123
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.079536800910304
# sqrt(5) 2.23606797749979
# diff is 0.001927085530610529
# val is 2.079536800910304
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.1254468890775007
# sqrt(5) 2.23606797749979
# diff is 0.0028906282959157937
# val is 2.1254468890775007
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.1949988416833617
# sqrt(5) 2.23606797749979
# diff is 0.003854171061221058
# val is 2.1949988416833617
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.2998532497110347
# sqrt(5) 2.23606797749979
# diff is 0.004817713826526323
# val is 2.2998532497110347
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.463121690138448
# sqrt(5) 2.23606797749979
# diff is 0.0057812565918315875
# val is 2.463121690138448
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.7324257573836026
# sqrt(5) 2.23606797749979
# diff is 0.0067447993571368514
# val is 2.7324257573836026
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 3.230362329455949
# sqrt(5) 2.23606797749979
# diff is 0.007708342122442116
# val is 3.230362329455949
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 4.510323652010944
# sqrt(5) 2.23606797749979
# diff is 0.00867188488774738
# val is 4.510323652010944
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.009635427653052645
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.01059897041835791
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.011562513183663175
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.01252605594896844
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.013489598714273703
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.014453141479578968
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.015416684244884233
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.016380227010189496
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.01734376977549476
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.018307312540800025
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.01927085530610529
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.020234398071410555
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.02119794083671582
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.022161483602021085
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.02312502636732635
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.024088569132631615
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.02505211189793688
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.02601565466324214
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.026979197428547406
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.02794274019385267
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.028906282959157936
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.0298698257244632
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.030833368489768465
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.03179691125507373
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.03276045402037899
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.03372399678568426
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.03468753955098952
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.03565108231629479
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.03661462508160005
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.03757816784690532
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.03854171061221058
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.03950525337751585
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.04046879614282111
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.04143233890812637
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.04239588167343164
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.0433594244387369
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.04432296720404217
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.04528650996934743
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.0462500527346527
# val is inf
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: inf
# sqrt(5) 2.23606797749979
# diff is 0.04721359549995796
# val is inf

# %%
sk.solve(constrFrac=1.0,minOnly=True,obsData=[0.4,0.4,0.4,0.4,0.4])
# Out:
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 2.0378734542869332
# sqrt(5) 2.23606797749979
# 2.0378734542869332

# %%
list2
# Out:
# [2.0378734542869332, 2.05133666324123, 2.079536800910304, 2.1254468890775007,
# 2.1949988416833617, 2.2998532497110347, 2.463121690138448, 2.7324257573836026,
#  3.230362329455949, 4.510323652010944, inf, inf, inf, inf, inf, inf, inf, inf,
#  inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, in
# f, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
# inf]

# %%
list1
# Out:
# array([0.        , 0.00096354, 0.00192709, 0.00289063, 0.00385417,
#        0.00481771, 0.00578126, 0.0067448 , 0.00770834, 0.00867188,
#        0.00963543, 0.01059897, 0.01156251, 0.01252606, 0.0134896 ,
#        0.01445314, 0.01541668, 0.01638023, 0.01734377, 0.01830731,
#        0.01927086, 0.0202344 , 0.02119794, 0.02216148, 0.02312503,
#        0.02408857, 0.02505211, 0.02601565, 0.0269792 , 0.02794274,
#        0.02890628, 0.02986983, 0.03083337, 0.03179691, 0.03276045,
#        0.033724  , 0.03468754, 0.03565108, 0.03661463, 0.03757817,
#        0.03854171, 0.03950525, 0.0404688 , 0.04143234, 0.04239588,
#        0.04335942, 0.04432297, 0.04528651, 0.04625005, 0.0472136 ])

# %%
import pandas
df = pandas.DataFrame(data={"Deviaton": list1, "Fidelity": list2})
df.to_csv("./Fid_KCBS_1.csv", sep=',',index=False)

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

list1 = np.linspace(0.00022448979591836734, 0.001, num=30)
list2 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] - diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list2.append(val1)
    print("diff is", diff)
    print("val is", val1)
# Out:
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.995234867570599
# sqrt(5) 2.23606797749979
# diff is 0.00022448979591836734
# val is 5.995234867570599
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...
# min: 5.990414599089788
# sqrt(5) 2.23606797749979
# diff is 0.00025123152709359607
# val is 5.990414599089788
# STEP  1 / 3  in progress...
# Updating observed constraints
# Observed values; Adding constraints
# Done.
# STEP  1 / 3  done.
#
#
# STEP  2 / 3  in progress...
# Readying the solver
# Using only  16859  of the total  16859  constraints
# STEP  2 / 3  done.
#
#
# STEP  3 / 3  in progress...
# Solving now
# Initialising...

# %%
list2

# %%
list1

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

list3 = np.linspace(0.001, 0.047, num=30)
list4 = []
for diff in list1:
    for i in range(len(obsData)):
        obsData[i] = obsData[i] - diff   
    val1= sk.solve(constrFrac=1.0,minOnly=True,obsData=obsData)
    list4.append(val1)
    print("diff is", diff)
    print("val is", val1)

# %%
N=5
obsData=[np.cos(np.pi / N) / (1 + np.cos(np.pi / N)) for i in range(N) ]

# %%
obsData

# %%
1/np.sqrt(5)
